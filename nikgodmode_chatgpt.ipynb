# %% [markdown]
# <a href="https://colab.research.google.com/github/placidnick/addTwoNumbers/blob/master/nikgodmode_chatgpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 2.8 MB/s eta 0:00:00
# ...

# %%
import openai

# Replace YOUR_API_KEY with your OpenAI API key
openai.api_key = "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"
# Set the model and prompt
model_engine = "text-davinci-003"
#prompt = "Write a blog on ChatGPT"
prompt = input('What\'s on your mind: ')
print(f'God heard your prayer: {prompt}')
prompt = prompt + " reply in style of a Lord Rama"


# Set the maximum number of tokens to generate in the response
max_tokens = 50

# Generate a response
completion = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=max_tokens,
    temperature=0.5,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
)

# Print the response
print(completion.choices[0].text)

#Create a talking video
import requests

url = "https://api.movio.la/v1/video.generate"

payload = {
    "background": "#ffffff",
    "clips": [
        {
            "avatar_style": "normal",
            "caption": False,
            "input_text": completion.choices[0].text,
            "scale": 1,
            "voice_id": "ef5765a5c2ee49e58f7dd942e67fb6f2",
            "talking_photo_style": "normal",
            "talking_photo_id": "6d864a9cb29043c6999043ee09be1117"
            #"talking_photo_id": "4b98876857e64a30885bc295676b8a93"
        }
    ],
    "ratio": "16:9",
    "test": False,
    "version": "v1alpha"
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "x-api-key": "NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng=="
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# What's on your mind: what is an ice cream
# God heard your prayer: what is an ice cream
#
#
# My dearest, the sweetest treat of all is the gift of divine grace, for it brings joy and peace to all.
# {"code":100,"data":{"video_id":"46a5545792e9491daf617188ec4f833d"},"message":"Success"}

# %%
api_key = "NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng=="
#video_id = "d4725c1e210649b19a52f06cb1546d58"
video_id = "46a5545792e9491daf617188ec4f833d"
url = f"https://api.movio.la/v1/video_status.get?video_id={video_id}"
headers = {
"X-Api-Key": api_key
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"code":100,"data":{"error":null,"id":"46a5545792e9491daf617188ec4f833d","status":"completed","video_url":"https://surreal-product.s3.amazonaws.com/aws_pacific/avatar_tmp/aa06d52c667244259d1188d4ad666170/ba11d77e-f318-47ae-bef2-8c56d51ae050.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAWTIFNQS3KRF4QRED%2F20230308%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20230308T090333Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=ee360b98e521ee933d6605392c5cf7ac9a0e8d02bf85deec86fa106c53523be9"},"message":"Success"}

# %%
import requests

download_url = "https://surreal-product.s3.amazonaws.com/aws_pacific/avatar_tmp/aa06d52c667244259d1188d4ad666170/ba11d77e-f318-47ae-bef2-8c56d51ae050.mp4?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAWTIFNQS3KRF4QRED%2F20230308%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20230308T090333Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=ee360b98e521ee933d6605392c5cf7ac9a0e8d02bf85deec86fa106c53523be9"
filename = "first_video.mp4"

response = requests.get(download_url)

with open(filename, "wb") as file:
    file.write(response.content)

print(f"File saved as {filename}")
# Out:
# File saved as first_video.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('first_video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=800 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=800 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
#backup working default code
import requests
import json

api_key = "NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng=="
url = "https://api.movio.la/v1/video.generate"
headers = {
"X-Api-Key": api_key,
"Content-Type": "application/json"
}

data = {
"background": "#ffffff",
"clips": [
{
"avatar_id": "a56e2f6f7777497fa5a249d84515b7f6",
"avatar_style": "normal",
"input_text": "Welcome to movio API",
"offset": {
"x": 0,
"y": 0
},
"scale": 1,
"voice_id": "6d9babc7adb744bbbc4e833815cd3520"
}
],
"ratio": "16:9",
"test": True,
"version": "v1alpha"
}

response = requests.post(url, headers=headers, data=json.dumps(data))

print(response.text)

# %%
! curl --location --request GET 'https://api.movio.la/v1/upload_url.get' --header 'x-api-key: NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng==' --header 'Content-Type: application/json' --data-raw '{"content_type": "image/jpeg"}'
# Out:
# {"code":100,"data":{"storage_key":"prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71.jpeg","upload_url":"https://surreal-product.s3.amazonaws.com/prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAWTIFNQS3KRF4QRED%2F20230306%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20230306T024728Z&X-Amz-Expires=600&X-Amz-SignedHeaders=host&X-Amz-Signature=6ea08e6f2fdf4040954cbf1b03ae1223d7e2d5903ae5d3c9bcdb52bbe6650af7"},"message":"Success"}

# %%
import requests

url = "https://api.movio.la/v1/talking_photo.create"

payload = {"storage_key": "prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71.jpeg"}

headers = {
    "accept": "application/json",
    "x-api-key": "NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng==",
    "content-type": "application/json"
}

response = requests.get(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"code":100,"data":{"cropped_height":241,"cropped_url":"https://files.movio.la/prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71_cropped.jpeg?Expires=1678675727&Signature=jbAjjCEmWCkpQaKqkVxLlhVc2uFnTcWTJW-YxLUnRHWPPpMLzdNBwhRh49AOEnfeAWokzuDgJun6kL61mU8ADLYE5S8HwwipCQjNZb2qhumkITZD70OYzVV1EE6jxDHgttGNQ5P6XJLWa-Jfs-PJsPqNkRq8hdaFrdAj~K~xzzns2UB2u2O3Ijt1JSrDZdRvJ~hl0FN1~SoiSTlHeDwo4Tyo2swPzCVV6SzG3UXXO3GUYXSR-35P-ouFez3mzLJJu6xaWYhDDnGAjBe2xBubNkVatKDhTgKl~aT7jskFP-OVLXi0hPCGnZqfrQoT5lksZMIuKw7FQyzHPIClZwXjhg__&Key-Pair-Id=K49TZTO9GZI6K","cropped_width":241,"enhanced_cropped_url":"https://files.movio.la/prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71_cropped_enhanced.jpeg?Expires=1678675727&Signature=WceZYIswonuITMTozUCdDN3gu3M6u5srBiqThEAmUwOnThD64gjCti0eB7h1cwwkiWw2vmRJaFApa5Le2TCPmNIqy0qssxq49V1Hw8nqrLtdOeZ0NMDd7wShvhlcfVArs~608sTTy0PsbGsl1HLBlzaAK-q6xG4hBHkFu6JHzoGlzzXXGWpEdqU2f7L
# ...

# %%
import requests
from pprint import pprint
url = "https://api.movio.la/v1/talking_photo.list"

headers = {
    "accept": "application/json",
    "x-api-key": "NTVkMTMyZjc0MWUyNGI1Zjk3NjdiYjEyMWVkNGExZTQtMTY3NzkxNDk5Ng=="
}

response = requests.get(url, headers=headers)

pprint(response.text)
# Out:
# '{"code":100,"data":[{"circle_image":"https://surreal-product.s3.amazonaws.com/prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71_cropped.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAWTIFNQS3KRF4QRED%2F20230306%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20230306T025144Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=f8c50e221828ab9d162441eac45481489cc77dc38f71de025fc0a5a9f4708677","id":"6d864a9cb29043c6999043ee09be1117","image_url":"https://surreal-product.s3.amazonaws.com/prod/movio/url_upload/user_upload/aa06d52c667244259d1188d4ad666170/a10c9d2b437f46afb54b1bff9a9dbe71.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAWTIFNQS3KRF4QRED%2F20230306%2Fus-east-2%2Fs3%2Faws4_request&X-Amz-Date=20230306T025144Z&X-Amz-Expires=604800&X-Amz-SignedHeaders=host&X-Amz-Signature=b6198248a8471542b697a689e185c5ba14a94a5c541f35009cd0a5f3c2b5db06"},{"circle_image":"https://surreal-product.s3.amazonaws.com/prod/mov
# ...

# %%
from pprint import pprint
stuff="this is test"
pprint(stuff)
# Out:
# 'this is test'
